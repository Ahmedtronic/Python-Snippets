# %%
import moviepy.editor

# %%
Video = moviepy.editor.VideoFileClip("Video Path")

# %%
Audio = Video.audio # conversion

# %%
Audio.ipython_display(maxduration = 300)
# Out:
# chunk:   2%|█▉                                                                                            | 37/1823 [00:00<00:04, 369.95it/s, now=None]
# MoviePy - Writing audio in __temp__.mp3
# MoviePy - Done.
# <div align=middle><audio controls><source   src='data:audio/mp3;base64,...'>Sorry, seems like your browser doesn't support HTML5 audio/video</audio></div>

# %%
Audio.write_audiofile("The Snipper song.mp3")
# Out:
# chunk:   2%|█▍                                                                                            | 29/1823 [00:00<00:06, 256.65it/s, now=None]
# MoviePy - Writing audio in The Snipper song.mp3
# MoviePy - Done.
